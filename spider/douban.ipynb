# %%
#-*- coding:utf-8 -*-
"""
-------------------------------------------------
   File Name：     DoubanBookTop250
   Author :        zww
   Date：          2019/5/13
   Change Activity:2019/5/13
-------------------------------------------------
"""
import csv
import requests
from lxml import etree

headers ={'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML,like Gecko) Chrome/63.0.3239.132 Safari/537.36'}
#获取每页地址
def getUrl():
    for i in range(10):
        url = 'https://book.douban.com/top250?start={}'.format(i*25)
        for item in urlData(url):
            write_to_file(item)
            print('test write')
        print('成功保存豆瓣图书Top250第{}页的数据!'.format(i+1))

#数据存储到csv
def write_to_file(content):
    #‘a’追加模式，‘utf_8_sig’格式到处csv不乱码
    with open('DoubanBookTop250.csv','a',encoding='utf_8_sig',newline='') as f:
        fieldnames = ['name','score','comment','info']
        #利用csv包的DictWriter函数将字典格式数据存储到csv文件中
        print('test')
        w = csv.DictWriter(f,fieldnames=fieldnames)
        w.writerow(content)

#获取每页数据
def urlData(url):
    html = requests.get(url,headers=headers).text
    res = etree.HTML(html)
    trs = res.xpath('//*[@id="content"]/div/div[1]/div/table/tr')
    for tr in trs:
        yield {
        'name':tr.xpath('./td[2]/div/a/text()')[0].strip(),
        'score':tr.xpath('./td[2]/div/span[2]/text()')[0].strip(),
        'comment':tr.xpath('./td[2]/div/span[3]/text()')[0].replace('(','').replace(')','').strip(),
        'info':tr.xpath('./td[2]/p[1]/text()')[0].strip()
        }
        #print("《{}》--{}分--{}--{}".format(name,score,comment,info))

if __name__ == '__main__':
    getUrl()
# Out:
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# 成功保存豆瓣图书Top250第1页的数据!
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# 成功保存豆瓣图书Top250第2页的数据!
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# 成功保存豆瓣图书Top250第3页的数据!
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# 成功保存豆瓣图书Top250第4页的数据!
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# test
# test write
# 成功保存豆瓣图书Top250第5页的数据!
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-6-d2f28c3a9d43> in <module>()
#      47
#      48 if __name__ == '__main__':
# ---> 49     getUrl()
#
# <ipython-input-6-d2f28c3a9d43> in getUrl()
#      18         url = 'https://book.douban.com/top250?start={}'.format(i*25)
#      19         for item in urlData(url):
# ---> 20             write_to_file(item)
#      21             print('test write')
#      22         print('成功保存豆瓣图书Top250第{}页的数据!'.format(i+1))
#
# <ipython-input-6-d2f28c3a9d43> in write_to_file(content)
#      25 def write_to_file(content):
#      26     #‘a’追加模式，‘utf_8_sig’格式到处csv不乱码
# ---> 27     with open('DoubanBookTop250.csv','a',encoding='utf_8_sig',newline='') as f:
#      28         fieldnames = ['name','score','comment','info']
#      29         #利用csv包的DictWriter函数将字典格式数据存储到csv文件中
#
# PermissionError: [Errno 13] Permission denied: 'DoubanBookTop250.csv'
